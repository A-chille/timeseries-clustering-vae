# %%
#making a list of sbatch commands they are in cluster_train folder

sbatch --time=08:00:00 --mem=14000 --cpus-per-task=4 --gres=gpu:1 main_size.sh
sbatch --time=08:00:00 --mem=14000 --cpus-per-task=4 --gres=gpu:1 main_sos.sh
sbatch --time=08:00:00 --mem=14000 --cpus-per-task=4 --gres=gpu:1 main_mcherry.sh
sbatch --time=08:00:00 --mem=14000 --cpus-per-task=4 --gres=gpu:1 main_size_sos.sh
sbatch --time=08:00:00 --mem=14000 --cpus-per-task=4 --gres=gpu:1 main_size_mcherry.sh
sbatch --time=08:00:00 --mem=14000 --cpus-per-task=4 --gres=gpu:1 main_sos_mcherry.sh
sbatch --time=08:00:00 --mem=14000 --cpus-per-task=4 --gres=gpu:1 main_size_sos_mcherry.sh
